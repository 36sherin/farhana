# %% [markdown]
# <a href="https://colab.research.google.com/github/36sherin/farhana/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
from transformers import pipeline
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %%
generator=pipeline("text-generation",model="gpt2")
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu

# %%
prompt="once upon a time,a little boy"
output=generator(prompt,max_length=50)
print(output[0]["generator_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# once upon a time,a little boy can be a hero. It's one of those things that all children should aspire to see happen."
#
# I'm sure other parents will have similar views.
#
# But we need to keep in mind that these are kids whose lives are being shaped by their parents. As they grow up and become adults, their lives will change by their own parents' actions. So don't get me wrong. We all have a right to grow up proud of our parents' actions, and that means we have an obligation to consider them in our own lives.
#
# ...

# %%
prompt="in 2026, i become major"
output=generator(prompt,max_length=30)
print(output[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# in 2026, i become major king. He is about to be sacked by the Arabs, and the country is under siege by the people of Persia, who have been compelled to fight back by the Romans. One day, a band of robbers comes to the king and takes him hostage, and when the king is on his way, he is attacked by a group of the Romans, who shoot and kill him. The king is sent to Babylon, and is ordered to go to Babylon and fight the Romans.
#
# ...
